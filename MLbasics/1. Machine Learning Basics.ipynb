# %%
# !pip install pandas

# %%
import pandas as pd
df =pd.read_csv('/content/demographics_data.csv')
df.head()
print('Machine Learning')
# Out:
# Machine Learning

# %%
!1s
# Out:
# /bin/bash: line 1: 1s: command not found

# %% [markdown]
# # Print **Funciton**
